# %%
import torch
import matplotlib.pyplot as plt

# %%
def find_memory_limit(start_size, scale_factor):
    """Returns:
     - tensor sizes
     - memory usage
    """
    size = start_size
    while True:
# Out:
#   File "<ipython-input-142-0022b97c57e0>", line 1
#     def find_memory_limit() -> list[int], list[int]:
#                                         ^
# SyntaxError: expected ':'
